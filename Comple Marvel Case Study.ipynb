# %%
import requests
import os
import hashlib
import json
import pandas as pd
from time import time
import string
from asyncio.windows_events import NULL

# %%
api_url = "http://gateway.marvel.com/v1/public/"
api_url_2 = "characters"
address = api_url + api_url_2
public_key = 'de89122dc1714c3f5adfea57a25e1474'
private_key = '01e29808b84258314ea1c092c14d69131df221cc'
limit = 100 

ts = str(int(time()))
hash_param = ts+private_key+public_key
hash_result = hashlib.md5(hash_param.encode())

params = {"apikey": public_key, 
            "ts": int(time()), 
            "hash": hash_result.hexdigest(),
            "limit": limit}

# %%
start_char = list(string.ascii_lowercase + string.digits)
start_char.remove('0')

df = pd.DataFrame()

for letter in start_char :
    params["nameStartsWith"] = letter
    response = requests.get(address, params)
    temp_df = pd.json_normalize(response.json(), record_path=['data', 'results'])
    df = pd.concat([df, temp_df], ignore_index=True)
    del params["nameStartsWith"]

# %%
df
# Out:
#            id                        name  \
# 0     1017100                A-Bomb (HAS)
# 1     1009144                      A.I.M.
# 2     1010699                 Aaron Stack
# 3     1009146  Abomination (Emil Blonsky)
# 4     1016823      Abomination (Ultimate)
# ...       ...                         ...
# 1394  1011127                      Zodiak
# 1395  1009741        Zombie (Simon Garth)
# 1396  1011183                       Zuras
# 1397  1009742                       Zzzax
# 1398  1011334                     3-D Man
#
#                                             description  \
# 0     Rick Jones has been Hulk's best bud since day ...
# 1     AIM is a terrorist organization bent on destro...
# 2
# 3     Formerly known as Emil Blonsky, a spy of Sovie...
# 4
# ...                                                 ...
# 1394  Twelve demons merged with Norman Harrison, who...
# 1395  War hero Simon Garth was turned into a zombie ...
# 1396         Zuras was once the leader of the Eternals.
# 1397  A chain reaction in an atomic reactor, a resul...
# 1398
#
#                       modified  \
# 0     2013-09-18T15:54:04-0400
# 1     2013-10-17T14:41:30-0400
# 2     1969-12-31T19:00:00-0500
# 3     2012-03-20T12:32:12-0400
# 4     2012-07-10T19:11:52-0400
# ...                        ...
# 1394  1969-12-31T19:00:00-0500
# 1395  1969-12-31T19:00:00-0500
# 1396  1969-12-31T19:00:00-0500
# 1397  2013-12-17T18:35:54-0500
# 1398  2014-04-29T14:18:17-0400
#
#                                             resourceURI  \
# 0     http://gateway.marvel.com/v1/public/characters...
# 1     http://gateway.marvel.com/v1/public/characters...
# 2     http://gateway.marvel.com/v1/public/characters...
# 3     http://gateway.marvel.com/v1/public/characters...
# 4     http://gateway.marvel.com/v1/public/characters...
# ...                                                 ...
# 1394  http://gateway.marvel.com/v1/public/characters...
# 1395  http://gateway.marvel.com/v1/public/characters...
# 1396  http://gateway.marvel.com/v1/public/characters...
# 1397  http://gateway.marvel.com/v1/public/characters...
# 1398  http://gateway.marvel.com/v1/public/characters...
#
#                                                    urls  \
# 0     [{'type': 'detail', 'url': 'http://marvel.com/...
# 1     [{'type': 'detail', 'url': 'http://marvel.com/...
# 2     [{'type': 'detail', 'url': 'http://marvel.com/...
# 3     [{'type': 'detail', 'url': 'http://marvel.com/...
# 4     [{'type': 'detail', 'url': 'http://marvel.com/...
# ...                                                 ...
# 1394  [{'type': 'detail', 'url': 'http://marvel.com/...
# 1395  [{'type': 'detail', 'url': 'http://marvel.com/...
# 1396  [{'type': 'detail', 'url': 'http://marvel.com/...
# 1397  [{'type': 'detail', 'url': 'http://marvel.com/...
# 1398  [{'type': 'detail', 'url': 'http://marvel.com/...
#
#                                          thumbnail.path thumbnail.extension  \
# 0     http://i.annihil.us/u/prod/marvel/i/mg/3/20/52...                 jpg
# 1     http://i.annihil.us/u/prod/marvel/i/mg/6/20/52...                 jpg
# 2     http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# 3     http://i.annihil.us/u/prod/marvel/i/mg/9/50/4c...                 jpg
# 4     http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# ...                                                 ...                 ...
# 1394  http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# 1395  http://i.annihil.us/u/prod/marvel/i/mg/6/10/4c...                 jpg
# 1396  http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# 1397  http://i.annihil.us/u/prod/marvel/i/mg/c/d0/4c...                 jpg
# 1398  http://i.annihil.us/u/prod/marvel/i/mg/c/e0/53...                 jpg
#
#       comics.available                               comics.collectionURI  \
# 0                    4  http://gateway.marvel.com/v1/public/characters...
# 1                   51  http://gateway.marvel.com/v1/public/characters...
# 2                   14  http://gateway.marvel.com/v1/public/characters...
# 3                   55  http://gateway.marvel.com/v1/public/characters...
# 4                    2  http://gateway.marvel.com/v1/public/characters...
# ...                ...                                                ...
# 1394                 1  http://gateway.marvel.com/v1/public/characters...
# 1395                 1  http://gateway.marvel.com/v1/public/characters...
# 1396                 3  http://gateway.marvel.com/v1/public/characters...
# 1397                 5  http://gateway.marvel.com/v1/public/characters...
# 1398                12  http://gateway.marvel.com/v1/public/characters...
#
#       ...                                       series.items  series.returned  \
# 0     ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                2
# 1     ...  [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 2     ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                3
# 3     ...  [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 4     ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                2
# ...   ...                                                ...              ...
# 1394  ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                1
# 1395  ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                1
# 1396  ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                3
# 1397  ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                4
# 1398  ...  [{'resourceURI': 'http://gateway.marvel.com/v1...                3
#
#       stories.available                              stories.collectionURI  \
# 0                     7  http://gateway.marvel.com/v1/public/characters...
# 1                    54  http://gateway.marvel.com/v1/public/characters...
# 2                    27  http://gateway.marvel.com/v1/public/characters...
# 3                    65  http://gateway.marvel.com/v1/public/characters...
# 4                     3  http://gateway.marvel.com/v1/public/characters...
# ...                 ...                                                ...
# 1394                  1  http://gateway.marvel.com/v1/public/characters...
# 1395                  1  http://gateway.marvel.com/v1/public/characters...
# 1396                  3  http://gateway.marvel.com/v1/public/characters...
# 1397                  6  http://gateway.marvel.com/v1/public/characters...
# 1398                 21  http://gateway.marvel.com/v1/public/characters...
#
#                                           stories.items  stories.returned  \
# 0     [{'resourceURI': 'http://gateway.marvel.com/v1...                 7
# 1     [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 2     [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 3     [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 4     [{'resourceURI': 'http://gateway.marvel.com/v1...                 3
# ...                                                 ...               ...
# 1394  [{'resourceURI': 'http://gateway.marvel.com/v1...                 1
# 1395  [{'resourceURI': 'http://gateway.marvel.com/v1...                 1
# 1396  [{'resourceURI': 'http://gateway.marvel.com/v1...                 3
# 1397  [{'resourceURI': 'http://gateway.marvel.com/v1...                 6
# 1398  [{'resourceURI': 'http://gateway.marvel.com/v1...                20
#
#       events.available                               events.collectionURI  \
# 0                    0  http://gateway.marvel.com/v1/public/characters...
# 1                    0  http://gateway.marvel.com/v1/public/characters...
# 2                    0  http://gateway.marvel.com/v1/public/characters...
# 3                    1  http://gateway.marvel.com/v1/public/characters...
# 4                    0  http://gateway.marvel.com/v1/public/characters...
# ...                ...                                                ...
# 1394                 0  http://gateway.marvel.com/v1/public/characters...
# 1395                 0  http://gateway.marvel.com/v1/public/characters...
# 1396                 0  http://gateway.marvel.com/v1/public/characters...
# 1397                 0  http://gateway.marvel.com/v1/public/characters...
# 1398                 1  http://gateway.marvel.com/v1/public/characters...
#
#                                            events.items  events.returned
# 0                                                    []                0
# 1                                                    []                0
# 2                                                    []                0
# 3     [{'resourceURI': 'http://gateway.marvel.com/v1...                1
# 4                                                    []                0
# ...                                                 ...              ...
# 1394                                                 []                0
# 1395                                                 []                0
# 1396                                                 []                0
# 1397                                                 []                0
# 1398  [{'resourceURI': 'http://gateway.marvel.com/v1...                1
#
# [1399 rows x 24 columns]

# %% [markdown]
# `Activity 3`

# %%
def get_df(nameStartWith, apikey, hash):
    
	"""
	returns a dataframe where character name starts with a specific string
	"""

	# if(apikey==NULL or md5hash==NULL):
	# 	raise Exception ("Hash and/or API key is not provided")
	api_url = "http://gateway.marvel.com/v1/public/character"

	try:
		params = {"apikey": apikey, "ts": int(time()), 
				"hash": hash, "nameStartsWith": nameStartWith,
				"limit" : 100}

		response = requests.get(api_url, params)
		df = pd.json_normalize(response.json(), record_path=['data','results'])
		return df
	except:
		print("Hash and/or API key is not provided")

# %% [markdown]
# `Activity 4`

# %%
def ch_filter(df1,col,filter_condition):
    return df1.query(col+filter_condition)

# %%
result2= ch_filter(df1=df, col='name',filter_condition='.str.startswith("A")')
result2
# Out:
#          id                        name  \
# 0   1017100                A-Bomb (HAS)
# 1   1009144                      A.I.M.
# 2   1010699                 Aaron Stack
# 3   1009146  Abomination (Emil Blonsky)
# 4   1016823      Abomination (Ultimate)
# ..      ...                         ...
# 79  1009163                      Aurora
# 80  1009164                   Avalanche
# 81  1009165                    Avengers
# 82  1015239         Avengers (Ultimate)
# 83  1011766             Azazel (Mutant)
#
#                                           description  \
# 0   Rick Jones has been Hulk's best bud since day ...
# 1   AIM is a terrorist organization bent on destro...
# 2
# 3   Formerly known as Emil Blonsky, a spy of Sovie...
# 4
# ..                                                ...
# 79
# 80
# 81  Earth's Mightiest Heroes joined forces to take...
# 82
# 83  A mutant from biblical times, Azazel is the ru...
#
#                     modified  \
# 0   2013-09-18T15:54:04-0400
# 1   2013-10-17T14:41:30-0400
# 2   1969-12-31T19:00:00-0500
# 3   2012-03-20T12:32:12-0400
# 4   2012-07-10T19:11:52-0400
# ..                       ...
# 79  2011-05-10T15:56:51-0400
# 80  2010-11-05T14:30:34-0400
# 81  2020-07-21T10:29:09-0400
# 82  2012-07-10T19:18:28-0400
# 83  2011-06-09T11:04:52-0400
#
#                                           resourceURI  \
# 0   http://gateway.marvel.com/v1/public/characters...
# 1   http://gateway.marvel.com/v1/public/characters...
# 2   http://gateway.marvel.com/v1/public/characters...
# 3   http://gateway.marvel.com/v1/public/characters...
# 4   http://gateway.marvel.com/v1/public/characters...
# ..                                                ...
# 79  http://gateway.marvel.com/v1/public/characters...
# 80  http://gateway.marvel.com/v1/public/characters...
# 81  http://gateway.marvel.com/v1/public/characters...
# 82  http://gateway.marvel.com/v1/public/characters...
# 83  http://gateway.marvel.com/v1/public/characters...
#
#                                                  urls  \
# 0   [{'type': 'detail', 'url': 'http://marvel.com/...
# 1   [{'type': 'detail', 'url': 'http://marvel.com/...
# 2   [{'type': 'detail', 'url': 'http://marvel.com/...
# 3   [{'type': 'detail', 'url': 'http://marvel.com/...
# 4   [{'type': 'detail', 'url': 'http://marvel.com/...
# ..                                                ...
# 79  [{'type': 'detail', 'url': 'http://marvel.com/...
# 80  [{'type': 'detail', 'url': 'http://marvel.com/...
# 81  [{'type': 'detail', 'url': 'http://marvel.com/...
# 82  [{'type': 'detail', 'url': 'http://marvel.com/...
# 83  [{'type': 'detail', 'url': 'http://marvel.com/...
#
#                                        thumbnail.path thumbnail.extension  \
# 0   http://i.annihil.us/u/prod/marvel/i/mg/3/20/52...                 jpg
# 1   http://i.annihil.us/u/prod/marvel/i/mg/6/20/52...                 jpg
# 2   http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# 3   http://i.annihil.us/u/prod/marvel/i/mg/9/50/4c...                 jpg
# 4   http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# ..                                                ...                 ...
# 79  http://i.annihil.us/u/prod/marvel/i/mg/f/10/4c...                 jpg
# 80  http://i.annihil.us/u/prod/marvel/i/mg/f/10/4c...                 jpg
# 81  http://i.annihil.us/u/prod/marvel/i/mg/9/20/51...                 jpg
# 82  http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
# 83  http://i.annihil.us/u/prod/marvel/i/mg/b/40/im...                 jpg
#
#     comics.available                               comics.collectionURI  ...  \
# 0                  4  http://gateway.marvel.com/v1/public/characters...  ...
# 1                 51  http://gateway.marvel.com/v1/public/characters...  ...
# 2                 14  http://gateway.marvel.com/v1/public/characters...  ...
# 3                 55  http://gateway.marvel.com/v1/public/characters...  ...
# 4                  2  http://gateway.marvel.com/v1/public/characters...  ...
# ..               ...                                                ...  ...
# 79                82  http://gateway.marvel.com/v1/public/characters...  ...
# 80                47  http://gateway.marvel.com/v1/public/characters...  ...
# 81              2037  http://gateway.marvel.com/v1/public/characters...  ...
# 82                39  http://gateway.marvel.com/v1/public/characters...  ...
# 83                 3  http://gateway.marvel.com/v1/public/characters...  ...
#
#                                          series.items  series.returned  \
# 0   [{'resourceURI': 'http://gateway.marvel.com/v1...                2
# 1   [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 2   [{'resourceURI': 'http://gateway.marvel.com/v1...                3
# 3   [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 4   [{'resourceURI': 'http://gateway.marvel.com/v1...                2
# ..                                                ...              ...
# 79  [{'resourceURI': 'http://gateway.marvel.com/v1...               18
# 80  [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 81  [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 82  [{'resourceURI': 'http://gateway.marvel.com/v1...               11
# 83  [{'resourceURI': 'http://gateway.marvel.com/v1...                3
#
#     stories.available                              stories.collectionURI  \
# 0                   7  http://gateway.marvel.com/v1/public/characters...
# 1                  54  http://gateway.marvel.com/v1/public/characters...
# 2                  27  http://gateway.marvel.com/v1/public/characters...
# 3                  65  http://gateway.marvel.com/v1/public/characters...
# 4                   3  http://gateway.marvel.com/v1/public/characters...
# ..                ...                                                ...
# 79                 94  http://gateway.marvel.com/v1/public/characters...
# 80                 54  http://gateway.marvel.com/v1/public/characters...
# 81               2868  http://gateway.marvel.com/v1/public/characters...
# 82                 33  http://gateway.marvel.com/v1/public/characters...
# 83                  4  http://gateway.marvel.com/v1/public/characters...
#
#                                         stories.items  stories.returned  \
# 0   [{'resourceURI': 'http://gateway.marvel.com/v1...                 7
# 1   [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 2   [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 3   [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 4   [{'resourceURI': 'http://gateway.marvel.com/v1...                 3
# ..                                                ...               ...
# 79  [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 80  [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 81  [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 82  [{'resourceURI': 'http://gateway.marvel.com/v1...                20
# 83  [{'resourceURI': 'http://gateway.marvel.com/v1...                 4
#
#     events.available                               events.collectionURI  \
# 0                  0  http://gateway.marvel.com/v1/public/characters...
# 1                  0  http://gateway.marvel.com/v1/public/characters...
# 2                  0  http://gateway.marvel.com/v1/public/characters...
# 3                  1  http://gateway.marvel.com/v1/public/characters...
# 4                  0  http://gateway.marvel.com/v1/public/characters...
# ..               ...                                                ...
# 79                 4  http://gateway.marvel.com/v1/public/characters...
# 80                 7  http://gateway.marvel.com/v1/public/characters...
# 81                33  http://gateway.marvel.com/v1/public/characters...
# 82                 0  http://gateway.marvel.com/v1/public/characters...
# 83                 0  http://gateway.marvel.com/v1/public/characters...
#
#                                          events.items  events.returned
# 0                                                  []                0
# 1                                                  []                0
# 2                                                  []                0
# 3   [{'resourceURI': 'http://gateway.marvel.com/v1...                1
# 4                                                  []                0
# ..                                                ...              ...
# 79  [{'resourceURI': 'http://gateway.marvel.com/v1...                4
# 80  [{'resourceURI': 'http://gateway.marvel.com/v1...                7
# 81  [{'resourceURI': 'http://gateway.marvel.com/v1...               20
# 82                                                 []                0
# 83                                                 []                0
#
# [84 rows x 24 columns]

# %% [markdown]
# `Activity 5`

# %%
import argparse
api_key = public_key
hash = hash_result
parser = argparse.ArgumentParser(description='Activity')
parser.add_argument("-apikey", "--api_key", help="adds api_key", default= NULL)
parser.add_argument("-hash", "--hash", help="adds hash", default= NULL)
args, unknown = parser.parse_known_args()   #add CLI arguements while executing in CLI

print("API KEY",args.api_key)
print("HASH",args.hash)
api_key = args.api_key
hash = args.hash
# Out:
# API KEY 0
# HASH 0
